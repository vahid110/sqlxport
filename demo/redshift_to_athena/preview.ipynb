# %% [markdown]
# # 📦 Preview Redshift UNLOAD Output
# This notebook loads a sample `.parquet` file from the Redshift UNLOAD export and displays its content.

# %%
import pyarrow.dataset as ds
import pandas as pd

# Update if needed
LOCAL_PARQUET_DIR = "tmp_unload"

dataset = ds.dataset(LOCAL_PARQUET_DIR, format="parquet")
df = dataset.to_table().to_pandas()
df.head()
